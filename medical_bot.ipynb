# %% [markdown]
# Problem statement :
#
# A QA chatbot (interacting with a pdf or word document ) is shown.
#
# The first method to come up with a QA chatbot is to use a load_QA_chain, with a chain type : stuff (taking entire document) or with map_reduce (separates document to batches if the document is long, getting a summary).
#
#
# Since the allowed number of context-length tokens is 4097, the chain type could be changed to map-reduce to address this problem.
#
#
# https://github.com/hwchase17/langchain/issues/1349

# %%
#!pip uninstall langchain

# !pip install --force-reinstall typing-extensions==4.5.0

# !pip install langchain openai chromadb tiktoken pypdf panel sentence_transformers
# !pip install faiss-gpu
# Out:
# Collecting typing-extensions==4.5.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
# Successfully installed typing-extensions-4.5.0
# Collecting langchain
#   Downloading langchain-0.0.256-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.1 MB/s eta 0:00:00
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 9.8 MB/s eta 0:00:00
# Collecting chromadb
#   Downloading chromadb-0.4.5-py3-none-any.whl (402 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 18.9 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.3 MB/s eta 0:00:00
# Collecting pypdf
#   Downloading pypdf-3.15.0-py3-none-any.whl (270 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.3/270.3 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: panel in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.8.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.2)
# Collecting dataclasses-json<0.6.0,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting langsmith<0.1.0,>=0.0.11 (from langchain)
#   Downloading langsmith-0.0.19-py3-none-any.whl (31 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.22.4)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.27.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 7.3 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.2 (from chromadb)
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi<0.100.0,>=0.95.2 (from chromadb)
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.7 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.9 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 60.1 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 87.4 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.9 MB/s eta 0:00:00
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2022.10.31)
# Requirement already satisfied: bokeh<3.3.0,>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from panel) (3.1.1)
# Requirement already satisfied: param>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from panel) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.10/dist-packages (from panel) (2.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from panel) (2023.7.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel) (3.4.4)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel) (0.4.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel) (6.0.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from panel) (1.5.3)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 116.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.3.0,>=3.1.1->panel) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.3.0,>=3.1.1->panel) (1.1.0)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.3.0,>=3.1.1->panel) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.3.0,>=3.1.1->panel) (9.4.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.3.0,>=3.1.1->panel) (6.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi<0.100.0,>=0.95.2->chromadb)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.7 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.6)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 46.0 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 109.6 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.6 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<3.3.0,>=3.1.1->panel) (2.1.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.2)
# Building wheels for collected packages: chroma-hnswlib, sentence_transformers, pypika
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.2-cp310-cp310-linux_x86_64.whl size=2285661 sha256=31042356e20bd4ac2244a3b2f4afe41a74741ea39240e5dae3f5a8953b08c39a
#   Stored in directory: /root/.cache/pip/wheels/11/2b/0d/ee457f6782f75315bb5828d5c2dc5639d471afbd44a830b9dc
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=5de9616c7a3e1b77ade84e4be5fe556cd257cff0a82f16f173def2c325bb8a18
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=abb94abd26b24a383a168b4baad1ab85fd19a1c79ebebc2c535b0fdfdcc32834
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built chroma-hnswlib sentence_transformers pypika
# Installing collected packages: tokenizers, sentencepiece, safetensors, pypika, monotonic, websockets, uvloop, requests, python-dotenv, pypdf, pulsar-client, overrides, mypy-extensions, marshmallow, humanfriendly, httptools, h11, chroma-hnswlib, backoff, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, posthog, openapi-schema-pydantic, langsmith, huggingface-hub, coloredlogs, transformers, openai, onnxruntime, fastapi, dataclasses-json, langchain, chromadb, sentence_transformers
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed backoff-2.2.1 chroma-hnswlib-0.7.2 chromadb-0.4.5 coloredlogs-15.0.1 dataclasses-json-0.5.14 fastapi-0.99.1 h11-0.14.0 httptools-0.6.0 huggingface-hub-0.16.4 humanfriendly-10.0 langchain-0.0.256 langsmith-0.0.19 marshmallow-3.20.1 monotonic-1.6 mypy-extensions-1.0.0 onnxruntime-1.15.1 openai-0.27.8 openapi-schema-pydantic-1.2.4 overrides-7.4.0 posthog-3.0.1 pulsar-client-3.2.0 pypdf-3.15.0 pypika-0.48.9 python-dotenv-1.0.0 requests-2.31.0 safetensors-0.3.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 starlette-0.27.0 tiktoken-0.4.0 tokenizers-0.13.3 transformers-4.31.0 typing-inspect-0.9.0 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.19.0 websockets-11.0.3
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 21.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
import openai
import os
import langchain #
import chromadb
import tiktoken
import pypdf
#from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders.csv_loader import CSVLoader
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import TextLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.vectorstores import FAISS
import panel as pn

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"
openai.api_key = "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"

# %% [markdown]
# #document loader

# %%
loader = CSVLoader("prepared_1.csv")
documents = loader.load()

# %%
documents
# Out:
# [Document(page_content='\ufeffQuestions: What is high blood pressure?\nResponse: High blood pressure is a condition where the force at which your heart pumps blood around your body is high. It is recorded with 2 numbers, the systolic pressure and the diastolic pressure, both measured in millimetres of mercury (mmHg).\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 0}),
#  Document(page_content='\ufeffQuestions: What are the risks of high blood pressure?\nResponse: Persistent high blood pressure can put extra strain on your blood vessels, heart, and other organs, such as the brain, kidneys, and eyes. It can increase your risk of serious and potentially life-threatening health conditions, such as heart disease, heart attacks, strokes, heart failure, peripheral arterial disease, aortic aneurysms, kidney disease, and vascular dementia.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 1}),
#  Document(page_content='\ufeffQuestions: How is high blood pressure diagnosed?\nResponse: The only way of knowing whether you have high blood pressure is to have a blood pressure test, which can be done at your GP surgery, some pharmacies, as part of your NHS Health Check, or in some workplaces. All adults over 40 are advised to have their blood pressure checked at least every 5 years.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 2}),
#  Document(page_content="\ufeffQuestions: What are the lifestyle changes that can help reduce blood pressure?\nResponse: Lifestyle changes that can help prevent and lower high blood pressure include reducing the amount of salt you eat and having a generally healthy diet, cutting back on alcohol, losing weight if you're overweight, exercising regularly, cutting down on caffeine, and stopping smoking.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 3}),
#  Document(page_content='\ufeffQuestions: What are the medicines used to control high blood pressure?\nResponse: Common blood pressure medicines include ACE inhibitors, angiotensin-2 receptor blockers (ARBs), calcium channel blockers, diuretics, beta blockers, alpha blockers, and other diuretics. The medicine recommended for you will depend on factors like how high your blood pressure is, your age, and your ethnicity.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 4}),
#  Document(page_content="\ufeffQuestions: What is considered to be ideal blood pressure?\nResponse: Ideal blood pressure is usually considered to be between 90/60mmHg and 120/80mmHg, while the target for over-80s is below 150/90mmHg (or 145/85mmHg at home), and high blood pressure is considered to be from 140/90mmHg (or an average of 135/85mmHg at home) â€“ or 150/90mmHg (or an average of 145/85mmHg at home) if you're over the age of 80.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 5}),
#  Document(page_content="\ufeffQuestions: How is blood pressure recorded?\nResponse: Blood pressure is recorded with 2 numbers which are the systolic pressure (higher number) is the force at which your heart pumps blood around your body, and the diastolic pressure (lower number) is the resistance to the blood flow in the blood vessels. They're both measured in millimetres of mercury (mmHg).\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 6}),
#  Document(page_content="\ufeffQuestions: What causes high blood pressure?\nResponse: It's not always clear what causes high blood pressure, but factors that can increase the risk include being overweight, eating too much salt and not eating enough fruit and vegetables, not doing enough exercise, drinking too much alcohol or coffee (or other caffeine-based drinks), smoking, not getting much sleep or having disturbed sleep, being over 65, having a relative with high blood pressure, being of black African or black Caribbean descent, and living in a deprived area.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 7}),
#  Document(page_content="\ufeffQuestions: Can lifestyle changes help reduce the risk of getting high blood pressure?\nResponse: Yes, making healthy lifestyle changes can sometimes help reduce your chances of getting high blood pressure and help lower your blood pressure if it's already high. These lifestyle changes include reducing the amount of salt you eat and having a generally healthy diet, cutting back on alcohol, losing weight if you're overweight, exercising regularly, cutting down on caffeine, and stopping smoking.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 8}),
#  Document(page_content='\ufeffQuestions: What are the potential health problems that can result from untreated high blood pressure?\nResponse: If untreated, high blood pressure increases your risk of serious problems such as heart disease, heart attacks, strokes, heart failure, peripheral arterial disease, aortic aneurysms, kidney disease, and vascular dementia.\nReferences:\n- https://www.nhs.uk/conditions/Blood-pressure-(high)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 9}),
#  Document(page_content='\ufeffQuestions: What is bronchiolitis?\nResponse: Bronchiolitis is a common chest infection that affects babies and children under 2, caused by a viral infection, usually the respiratory syncytial virus (RSV).\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 10}),
#  Document(page_content='\ufeffQuestions: What are the early symptoms of bronchiolitis?\nResponse: The early symptoms of bronchiolitis are similar to a cold, such as sneezing, a runny or blocked nose, a cough, and a slightly high temperature of 38C.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 11}),
#  Document(page_content='\ufeffQuestions: What should I do if my child is having trouble breathing due to bronchiolitis?\nResponse: If your child is having difficulty breathing, such as grunting noises, pauses when breathing, blue skin, tongue or lips, or floppiness, then you should call 999 or go to A&E.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 12}),
#  Document(page_content='\ufeffQuestions: Is bronchiolitis the same as bronchitis?\nResponse: No, bronchiolitis is different from bronchitis, which causes a cough with lots of mucus and can affect people of all ages.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 13}),
#  Document(page_content="\ufeffQuestions: What are the treatments for bronchiolitis?\nResponse: There's no specific treatment for bronchiolitis. It usually gets better on its own and you can look after your child at home. You can give children's paracetamol, try using saline drops, keep them upright, encourage fluids, and don't smoke around them.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 14}),
#  Document(page_content='\ufeffQuestions: What should I do if my child has a dry nappy for 12 hours or more?\nResponse: If your child has a dry nappy for 12 hours or more, or shows other signs of dehydration, then you should ask for an urgent GP appointment or call 111.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 15}),
#  Document(page_content="\ufeffQuestions: What increases a child's risk of severe bronchiolitis?\nResponse: Children who were born very prematurely, have a heart or lung condition, or have a weakened immune system may have a higher risk of getting seriously ill with bronchiolitis.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 16}),
#  Document(page_content="\ufeffQuestions: Can I prevent my child from getting bronchiolitis?\nResponse: You can lower the chances of your child getting bronchiolitis by washing your hands and your child's hands often, washing or wiping down toys and clean surfaces regularly, using disposable tissues, keeping newborn babies away from anyone with a cold or flu, and not smoking around your child.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 17}),
#  Document(page_content="\ufeffQuestions: What is the respiratory syncytial virus (RSV)?\nResponse: The respiratory syncytial virus is the common virus that causes bronchiolitis, which spreads easily in coughs and sneezes and almost all children have had it by the time they're 2.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 18}),
#  Document(page_content='\ufeffQuestions: How long does it take for bronchiolitis to improve?\nResponse: Symptoms are usually worst between days 3 and 5, and the cough usually gets better in 3 weeks.\nReferences:\n- https://www.nhs.uk/conditions/Bronchiolitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 19}),
#  Document(page_content='\ufeffQuestions: What is bronchitis?\nResponse: Bronchitis is an inflammation of the airways in the lungs that is usually caused by an infection. It often gets better without treatment in around 3 weeks.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 20}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of bronchitis?\nResponse: Symptoms of bronchitis can be similar to a cold or flu. Symptoms include coughing, chest pain when coughing, shortness of breath, a sore throat, a runny nose, and a high temperature.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 21}),
#  Document(page_content='\ufeffQuestions: What can I do to ease the symptoms of bronchitis?\nResponse: There are some things you can do to ease the symptoms of bronchitis and reduce the risk of spreading infections to other people. You can get plenty of rest, drink plenty of fluids, take painkillers like paracetamol or ibuprofen, try adding honey to a warm drink to help soothe your throat, cover your mouth and nose with a tissue when you cough or sneeze, and wash your hands regularly with water and soap.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 22}),
#  Document(page_content='\ufeffQuestions: Should I smoke if I have bronchitis?\nResponse: No, you should not smoke if you have bronchitis.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 23}),
#  Document(page_content="\ufeffQuestions: When should I call for an urgent GP appointment if I have bronchitis?\nResponse: You should ask for an urgent GP appointment or get help from NHS 111 if you've had a cough for more than 3 weeks, you cough up blood or blood-stained mucus, you have chest pain that comes and goes, or when breathing or coughing, you're over 65, you're pregnant, you have a long-term condition, such as diabetes, or a heart, lung or kidney condition, you have a weakened immune system, or you feel very unwell.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 24}),
#  Document(page_content="\ufeffQuestions: When should I call 999 if I have bronchitis?\nResponse: You should call 999 if you are struggling to breathe â€“ you are choking, gasping and unable to speak, you have pale, blue or blotchy skin, lips or tongue, you suddenly feel confused, or you're unable to wake your baby or they feel floppy.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 25}),
#  Document(page_content='\ufeffQuestions: How long does bronchitis usually last?\nResponse: Bronchitis usually clears up without treatment in around 3 weeks.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 26}),
#  Document(page_content='\ufeffQuestions: What is chronic bronchitis?\nResponse: Chronic bronchitis is long-term inflammation of the airways in the lungs. It is known as chronic obstructive pulmonary disease (COPD).\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 27}),
#  Document(page_content='\ufeffQuestions: What treatments are available for bronchitis?\nResponse: Bronchitis usually clears up without treatment in around 3 weeks. See a GP if your symptoms last longer than 3 weeks. You may need antibiotics if your bronchitis is caused by a bacterial infection.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 28}),
#  Document(page_content='\ufeffQuestions: Can babies under 1 year old have honey to soothe their throat if they have bronchitis?\nResponse: No, you should not give honey to babies under 1 to soothe their throat if they have bronchitis.\nReferences:\n- https://www.nhs.uk/conditions/Bronchitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 29}),
#  Document(page_content='\ufeffQuestions: What are steroids used for?\nResponse: Steroids are used to treat a variety of conditions such as asthma, hay fever, hives and eczema, painful joints or muscles, pain caused by an irritated or trapped nerve, inflammatory bowel disease, lupus, multiple sclerosis (MS), and others.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 30}),
#  Document(page_content='\ufeffQuestions: What are the main types of steroids?\nResponse: The main types of steroids are tablets, syrups and liquids, inhalers, nasal sprays, injections, creams, lotions, and gels. Each form has a specific purpose and is used to treat different types of conditions.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 31}),
#  Document(page_content='\ufeffQuestions: What is the difference between corticosteroids and anabolic steroids?\nResponse: Corticosteroids are a type of steroid used to treat various medical conditions like inflammation, asthma, COPD, and allergic reactions, while anabolic steroids are often used illegally to increase muscle mass and athletic performance.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 32}),
#  Document(page_content='\ufeffQuestions: What are the side effects of steroid tablets?\nResponse: Steroid tablets can cause various side effects such as an increased appetite, mood changes, difficulty sleeping, weight gain, increased blood sugar levels, and an increased susceptibility to infections.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 33}),
#  Document(page_content='\ufeffQuestions: What should I do if I experience side effects of steroid tablets?\nResponse: If you are experiencing side effects of steroid tablets, do not stop taking your medicine without speaking to your doctor first, as stopping a prescribed course of medicine can cause further unpleasant side effects (withdrawal symptoms).\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 34}),
#  Document(page_content='\ufeffQuestions: How do steroids work?\nResponse: Steroids work by reducing redness and swelling (inflammation) when the body is exposed to allergens or irritants. They also help to suppress the immune system to treat autoimmune conditions such as lupus, rheumatoid arthritis which are caused by the immune system attacking the body.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 35}),
#  Document(page_content='\ufeffQuestions: Are steroids dangerous to use?\nResponse: Steroids can cause a range of side effects but if they are taken for a short time or at a low dose under the supervision of a doctor, they typically do not cause any significant harm. However, long-term use of steroids can lead to more severe side effects.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 36}),
#  Document(page_content='\ufeffQuestions: Does the body produce steroids?\nResponse: Yes, the adrenal glands which are found above the kidneys produce natural steroids. When steroids are taken in doses higher than the amount the body normally produces, they can reduce inflammation and swelling.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 37}),
#  Document(page_content='\ufeffQuestions: Which conditions can be treated with steroid injections?\nResponse: Steroid injections can be used to treat painful joint conditions such as arthritis, tennis elbow, frozen shoulder, as well as sciatica and other conditions that cause pain caused by an irritated or trapped nerve.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 38}),
#  Document(page_content='\ufeffQuestions: What is the Yellow Card Scheme?\nResponse: The Yellow Card Scheme is a program that allows people to report suspected side effects of medicines in the UK. It is run by the Medicines and Healthcare products Regulatory Agency (MHRA) and helps to identify new side effects that were not previously known.\nReferences:\n- https://www.nhs.uk/conditions/Corticosteroid-(drugs)/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 39}),
#  Document(page_content='\ufeffQuestions: What is Creutzfeldt-Jakob disease?\nResponse: Creutzfeldt-Jakob disease is a rare and fatal brain condition that causes rapid and irreversible damage to nerve cells. Its symptoms include loss of intellect and memory, changes in personality, and abnormal jerking movements.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 40}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of CJD?\nResponse: Symptoms of CJD include loss of intellect and memory, changes in personality, slurred speech, vision problems, abnormal jerking movements, and progressive loss of brain function and mobility. Most people with CJD die within a year of the onset of symptoms.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 41}),
#  Document(page_content='\ufeffQuestions: What causes CJD?\nResponse: CJD is caused by abnormal infectious proteins called prions that accumulate at high levels in the brain and cause irreversible damage to nerve cells. These prions are highly resistant to heat and radiation, and antibiotics or antiviral medicines have no effect on them.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 42}),
#  Document(page_content='\ufeffQuestions: How many types of CJD are there?\nResponse: There are four main types of CJD: sporadic, variant, familial or inherited, and iatrogenic.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 43}),
#  Document(page_content='\ufeffQuestions: What is the most common type of CJD?\nResponse: The most common type of CJD is sporadic CJD, which affects about 1 or 2 people in every million each year in the UK. It is also the least understood and its causes remain unclear.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 44}),
#  Document(page_content='\ufeffQuestions: What is variant CJD?\nResponse: Variant CJD (vCJD) is a type of CJD that is likely caused by consuming meat from a cow infected with bovine spongiform encephalopathy (BSE), also known as â€œmad cowâ€\x9d disease. It can also be transmitted by blood transfusion. Strict controls have been implemented to prevent infected meat from entering the food chain.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 45}),
#  Document(page_content='\ufeffQuestions: What is familial CJD?\nResponse: Familial CJD is a rare genetic condition where a person inherits a mutated prion protein gene from their parent, causing prions to form in their brain and triggering the symptoms of CJD. It affects about 1 in every 9 million people in the UK.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 46}),
#  Document(page_content='\ufeffQuestions: What is iatrogenic CJD?\nResponse: Iatrogenic CJD is a type of CJD that is accidentally spread from someone with the disease through medical or surgical treatment. It can also occur if instruments used during brain surgery on a person with the disease are not properly cleaned between each surgical procedure and are reused on another person.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 47}),
#  Document(page_content='\ufeffQuestions: Is there a cure for CJD?\nResponse: Currently, there is no cure for CJD. Treatment aims to relieve symptoms and make the affected person feel as comfortable as possible. This can include using medication such as antidepressants and painkillers, as well as nursing care and assisted feeding.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 48}),
#  Document(page_content='\ufeffQuestions: Is there a compensation scheme for variant CJD victims?\nResponse: Yes, in October 2001, the UK government announced a compensation scheme for victims of variant CJD. The vCJD Trust assesses claims and pays compensation to victims and their families.\nReferences:\n- https://www.nhs.uk/conditions/Creutzfeldt-Jakob-disease/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 49}),
#  Document(page_content='\ufeffQuestions: What is HIV?\nResponse: HIV is a virus that weakens your immune system by damaging its cells, making it harder for your body to fight infections and diseases.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 50}),
#  Document(page_content='\ufeffQuestions: How is AIDS different from HIV?\nResponse: AIDS is a collection of potentially life-threatening illnesses that occur when your immune system has been severely damaged by HIV. AIDS cannot be transmitted from one person to another, but HIV can.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 51}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of HIV?\nResponse: Most people experience a short flu-like illness 2 to 6 weeks after HIV infection, which lasts for a week or 2. After these symptoms disappear, HIV may not cause any symptoms for many years, although the virus continues to damage your immune system.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 52}),
#  Document(page_content='\ufeffQuestions: How is HIV diagnosed?\nResponse: You can get tested for HIV at a GP surgery, sexual health clinics and clinics run by charities. Specialized testing services are also available online and from pharmacies. The only way to find out if you have HIV is to have an HIV test. This involves testing a sample of your blood or saliva for signs of the infection.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 53}),
#  Document(page_content='\ufeffQuestions: What are the causes of HIV?\nResponse: HIV is found in the body fluids of an infected person, including semen, vaginal and anal fluids, blood, and breast milk. HIV cannot be transmitted through sweat, urine, or saliva. The most common way of getting HIV in the UK is through having anal or vaginal sex without a condom.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 54}),
#  Document(page_content='\ufeffQuestions: How is HIV treated?\nResponse: Antiretroviral medicines are used to treat HIV. They work by stopping the virus from replicating in the body, allowing the immune system to repair itself and preventing further damage. The goal of HIV treatment is to have an undetectable viral load. Most people with HIV take a combination of medicines, which need to be taken every day as recommended by your doctor.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 55}),
#  Document(page_content="\ufeffQuestions: What is post-exposure prophylaxis (PEP)?\nResponse: PEP is an emergency anti-HIV medicine that may stop you from becoming infected if started within 72 hours of possible exposure to the virus. It's recommended that you start it as soon as possible, ideally within 24 hours.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 56}),
#  Document(page_content='\ufeffQuestions: How can HIV be prevented?\nResponse: There are many effective ways to prevent or reduce the risk of HIV infection, including using a condom for sex, post-exposure prophylaxis (PEP), pre-exposure prophylaxis (PrEP), treatment for HIV to reduce the viral load to undetectable, and not sharing needles or other injecting equipment used to take drugs. Speak to your local sexual health clinic or a GP for further advice about the best way to reduce your risk.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 57}),
#  Document(page_content="\ufeffQuestions: Can HIV be passed on during oral sex?\nResponse: The chance of getting HIV through oral sex is very low and will be dependent on many things, such as whether you receive or give oral sex and the oral hygiene of the person giving the oral sex. However, it's still important to use protection, such as a dental dam or a condom, to reduce your risk of contracting the virus.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 58}),
#  Document(page_content="\ufeffQuestions: Can HIV be transmitted from a mother to a baby during pregnancy?\nResponse: Yes, HIV can be transmitted from a mother to a baby during pregnancy, childbirth, or breastfeeding. However, with the right treatment, the risk of transmission can be greatly reduced. If you're planning on getting pregnant and have HIV, it's important to talk to a GP.\nReferences:\n- https://www.nhs.uk/conditions/HIV/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 59}),
#  Document(page_content='\ufeffQuestions: What is a heart attack?\nResponse: A heart attack, also known as myocardial infarction (MI), is a medical emergency in which the blood supply to the heart is suddenly blocked, usually by a blood clot. This can cause serious damage to the heart muscle and can be life-threatening if not treated promptly.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 60}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of a heart attack?\nResponse: Symptoms of a heart attack can include chest pain, pain in other parts of the body such as the arms, jaw, neck, back, and tummy, lightheadedness or dizziness, sweating, shortness of breath, feeling sick or vomiting, an overwhelming feeling of anxiety, and coughing or wheezing. The severity and type of symptoms can vary between men and women.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 61}),
#  Document(page_content='\ufeffQuestions: What should I do if someone has a heart attack?\nResponse: If you suspect someone is having a heart attack, call 999 immediately and ask for an ambulance. While waiting for the ambulance, it may help to chew and then swallow a tablet of aspirin (ideally 300mg), as long as the person having a heart attack is not allergic to aspirin.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 62}),
#  Document(page_content='\ufeffQuestions: What is the leading cause of heart attacks?\nResponse: Coronary heart disease (CHD) is the leading cause of heart attacks. This is a condition in which the major blood vessels that supply the heart get clogged with deposits of cholesterol, known as plaques. Before a heart attack, one of these plaques may burst, causing a blood clot to develop at the site of the rupture and block the supply of blood to the heart.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 63}),
#  Document(page_content='\ufeffQuestions: What are the treatments for a heart attack?\nResponse: In a hospital, treatment for a heart attack depends on how serious it is. The two main treatments are using medicines to dissolve blood clots and surgery to help restore blood flow to the heart. While waiting for an ambulance, it may help to chew and then swallow a tablet of aspirin (ideally 300mg), as long as the person having a heart attack is not allergic to aspirin.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 64}),
#  Document(page_content='\ufeffQuestions: How long does it take to recover from a heart attack?\nResponse: The time it takes to recover from a heart attack depends on the amount of damage to the heart muscle. Most people can return to work after having a heart attack. Some people are well enough to return to work after 2 weeks. Other people may take several months to recover. How quickly you can go back to work depends on your health, the state of your heart, and the type of work you do.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 65}),
#  Document(page_content='\ufeffQuestions: What are the complications of a heart attack?\nResponse: Complications of a heart attack can be serious and possibly life-threatening. These include arrhythmias, cardiogenic shock, and heart rupture. These can happen quickly after a heart attack and are a leading cause of death. Factors such as age, the severity of the heart attack, and the time it took before treatment can affect the outlook.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 66}),
#  Document(page_content='\ufeffQuestions: What steps can I take to reduce my risk of having a heart attack?\nResponse: There are 5 main steps you can take to reduce your risk of having a heart attack or having another heart attack: quit smoking if you are a smoker, lose weight if you are overweight or obese, exercise regularly, eat a low-fat, high-fibre diet including whole grains and fruits and vegetables, and moderate your alcohol consumption.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 67}),
#  Document(page_content='\ufeffQuestions: Can women have different symptoms than men during a heart attack?\nResponse: Yes, while chest pain is the most common symptom in both men and women during a heart attack, women are more likely to experience other symptoms such as shortness of breath, feeling or being sick, and back or jaw pain.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 68}),
#  Document(page_content="\ufeffQuestions: How can I reduce my risk of having another heart attack?\nResponse: After experiencing a heart attack, it's important to take steps to lower your risk of having another one. This can include making lifestyle changes such as eating a healthy diet, exercising regularly, and quitting smoking. Your doctor may also prescribe medications such as statins to help lower your cholesterol levels and reduce your risk of another heart attack. Cardiac rehabilitation can also help you gradually restore your physical fitness so you can resume normal activities.\nReferences:\n- https://www.nhs.uk/conditions/Heart-attack/Pages/Introduction.aspx <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 69}),
#  Document(page_content='\ufeffQuestions: What is laryngitis?\nResponse: Laryngitis is when your voice box or vocal cords in the throat become irritated or swollen.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 70}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of laryngitis?\nResponse: The main symptoms of laryngitis are a hoarse (croaky) voice, sometimes losing your voice, an irritating cough that does not go away, always needing to clear your throat, and a sore throat. Children can also have a temperature of 38C or above, be off their food or drink, and have difficulty breathing (but this is rare).\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 71}),
#  Document(page_content='\ufeffQuestions: What can I do to treat laryngitis myself?\nResponse: You can try to speak as little as possible, drink plenty of fluids, keep the air moist by putting out bowls of water, gargle with warm salty water, and avoid talking loudly or whispering, smoking, spending time in smoky or dusty places, and drinking too much caffeine or alcohol.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 72}),
#  Document(page_content='\ufeffQuestions: What can a pharmacist do to help with laryngitis?\nResponse: A pharmacist can give advice and suggest treatments, including paracetamol or ibuprofen, cough syrup to help with your cough, and solutions to gargle or lozenges for the pain.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 73}),
#  Document(page_content="\ufeffQuestions: When should I see a GP for laryngitis?\nResponse: You should see a GP if your symptoms do not improve after 2 weeks, it's very painful or it's difficult to swallow, or you keep getting laryngitis or voice problems.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 74}),
#  Document(page_content='\ufeffQuestions: How can I gargle with salty water?\nResponse: To gargle with salty water, dissolve half a teaspoon of salt in a glass of warm water, gargle with the solution, then spit it out. Do not swallow it. Repeat as often as you like. This is not suitable for younger children.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 75}),
#  Document(page_content='\ufeffQuestions: What will a GP do if I have laryngitis?\nResponse: The GP will try to work out what has caused your laryngitis by looking inside your throat using a small mirror, wiping a cotton bud around the back of your throat for testing, arranging a blood test, or referring you to an ear, nose and throat (ENT) specialist (if you keep getting laryngitis). If your laryngitis is caused by an infection, the GP might prescribe antibiotics.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 76}),
#  Document(page_content='\ufeffQuestions: What are the possible causes of laryngitis?\nResponse: Laryngitis usually happens when you have an infection from a virus, such as cold or flu. Other things that cause laryngitis include allergies to things like dust and fumes, acid from your stomach coming up your throat (acid reflux), coughing over a long time, and clearing your throat all the time.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 77}),
#  Document(page_content='\ufeffQuestions: Can I prevent laryngitis?\nResponse: You can help prevent laryngitis by practicing good hygiene, such as washing your hands frequently, avoiding contact with people who have colds or flu, and getting a flu vaccination. You can also avoid smoking and exposure to secondhand smoke or other irritants, and manage conditions that can cause laryngitis, such as acid reflux or allergies.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 78}),
#  Document(page_content='\ufeffQuestions: When should I call 999 or go to A&E for laryngitis?\nResponse: You should call 999 or go to A&E if you or your child are having difficulty breathing.\nReferences:\n- https://www.nhs.uk/conditions/Laryngitis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 79}),
#  Document(page_content="\ufeffQuestions: What is multiple sclerosis?\nResponse: Multiple sclerosis (MS) is a condition that can affect the brain and spinal cord, causing a wide range of potential symptoms, including problems with vision, arm or leg movement, sensation, or balance. It's a lifelong condition that can sometimes cause serious disability, although it can occasionally be mild.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 80}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of multiple sclerosis?\nResponse: The symptoms of MS vary widely from person to person and can affect any part of the body. The main symptoms include fatigue, difficulty walking, vision problems, such as blurred vision, problems controlling the bladder, numbness or tingling in different parts of the body, muscle stiffness and spasms, problems with balance and coordination, problems with thinking, learning, and planning.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 81}),
#  Document(page_content='\ufeffQuestions: What are the types of multiple sclerosis?\nResponse: MS starts in 1 of 2 general ways: with individual relapses (attacks or exacerbations) or with gradual progression. The types include Relapsing remitting MS, Primary progressive MS, and Secondary progressive MS.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 82}),
#  Document(page_content='\ufeffQuestions: What causes multiple sclerosis?\nResponse: MS is an autoimmune condition. This is when something goes wrong with the immune system and it mistakenly attacks a healthy part of the body â€“ in this case, the brain or spinal cord of the nervous system. In MS, the immune system attacks the layer that surrounds and protects the nerves called the myelin sheath. Exactly what causes the immune system to act in this way is unclear, but most experts think a combination of genetic and environmental factors is involved.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 83}),
#  Document(page_content="\ufeffQuestions: What treatments are available for multiple sclerosis?\nResponse: There's currently no cure for MS, but a number of treatments can help control the condition and ease symptoms. The treatment you need will depend on the specific symptoms and difficulties you have. It may include treating relapses with short courses of steroid medicine to speed up recovery, specific treatments for individual MS symptoms, and treatment to reduce the number of relapses using medicines called disease-modifying therapies.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 84}),
#  Document(page_content="\ufeffQuestions: What are disease-modifying therapies?\nResponse: Disease-modifying therapies are medicines that may help to slow or reduce the overall worsening of disability in people with relapsing remitting MS, and in some people with primary and secondary progressive MS who have relapses. Unfortunately, there's currently no treatment that can slow the progress of primary progressive MS or secondary progressive MS, where there are no relapses. Many therapies aiming to treat progressive MS are currently being researched.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 85}),
#  Document(page_content='\ufeffQuestions: What is the life expectancy for people with multiple sclerosis?\nResponse: The average life expectancy for people with MS is around 5 to 10 years lower than average, and this gap appears to be getting smaller all the time. MS itself is rarely fatal, but complications may arise from severe MS, such as chest or bladder infections or swallowing difficulties.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 86}),
#  Document(page_content="\ufeffQuestions: At what age is multiple sclerosis commonly diagnosed?\nResponse: MS is most commonly diagnosed in people in their 20s, 30s, and 40s, although it can develop at any age. It's about 2 to 3 times more common in women than men. MS is one of the most common causes of disability in younger adults.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 87}),
#  Document(page_content="\ufeffQuestions: What should I do if I think I have MS?\nResponse: See a GP if you're worried you might have signs of MS. The symptoms often have many other causes, so they're not necessarily a sign of MS. Let the GP know about the specific pattern of symptoms you're experiencing. If they think you could have MS, you'll be referred to a specialist in conditions of the nervous system (a neurologist) who may suggest tests such as an MRI scan to check for features of MS.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 88}),
#  Document(page_content="\ufeffQuestions: Is there any support available for people with multiple sclerosis?\nResponse: There are 2 main MS charities in the UK â€“ MS Society and MS Trust. These organisations offer useful advice, publications, news items about ongoing research, blogs and chatrooms. They can be very useful if you, or someone you know, has just been diagnosed with MS. There's also the shift.ms website, an online community for younger people affected by MS.\nReferences:\n- https://www.nhs.uk/conditions/Multiple-sclerosis <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 89}),
#  Document(page_content='\ufeffQuestions: What is pneumonia?\nResponse: Pneumonia is inflammation of the lungs and is usually caused by an infection, either bacterial or viral. It can also be caused by something getting into your lungs, such as water or food.\nReferences:\n- https://www.nhs.uk/conditions/Pneumonia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 90}),
#  Document(page_content='\ufeffQuestions: What are the symptoms of pneumonia?\nResponse: The symptoms of pneumonia include coughing up yellow or green mucus, shortness of breath, a high temperature, chest pain, an aching body, feeling very tired, loss of appetite, making wheezing noises when you breathe, feeling confused.\nReferences:\n- https://www.nhs.uk/conditions/Pneumonia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 91}),
#  Document(page_content='\ufeffQuestions: How long does it take to recover from pneumonia?\nResponse: Most people get better in 2 to 4 weeks. However, babies, older people, and people with heart or lung conditions are at risk of getting seriously ill and may need treatment in the hospital.\nReferences:\n- https://www.nhs.uk/conditions/Pneumonia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 92}),
#  Document(page_content="\ufeffQuestions: What are the urgent symptoms that require immediate medical attention related to pneumonia?\nResponse: If you're coughing up blood or having chest pain that comes and goes when you breathe or cough, feeling short of breath or struggling to breathe, experiencing pale, blue, or blotchy skin, lips, or tongue, feeling confused or unable to wake your baby, then call 999 for immediate medical attention.\nReferences:\n- https://www.nhs.uk/conditions/Pneumonia/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 93}),
#  Document(page_content="\ufeffQuestions: What is the treatment for pneumonia?\nResponse: Antibiotics are usually prescribed to treat pneumonia, and the standard recovery time is 2 to 4 weeks. If you have pre-existing heart conditions, lung disease or you're over 65 years old, you may need hospital treatment, which includes fluids, antibiotics, and oxygen to help you breathe.\nReferences:\n- https://www.nhs.uk/conditions/Pneumonia/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 94}),
# ...
#  Document(page_content='\ufeffQuestions: What are the treatments for ATTR amyloidosis?\nResponse: Treatment for ATTR amyloidosis depends on the severity and type of the disease. Medicines such as patisiran and inotersen are used to treat ATTR and have shown promising results. These drugs can reduce disability, improve quality of life, and slow down the progression of the illness. Some types of inherited ATTR amyloidosis can be treated with a liver transplant. Heart failure can be treated by carefully controlling the amount of salt you have and how much you drink and by taking drugs for heart failure. Heart transplantation may very rarely be an option.\nReferences:\n- https://www.nhs.uk/conditions/amyloidosis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 968}),
#  Document(page_content='\ufeffQuestions: What is the role of the National Congenital Anomaly and Rare Disease Registration Service (NCARDRS)?\nResponse: The National Congenital Anomaly and Rare Disease Registration Service collects information about people with rare diseases, including amyloidosis. If a person has amyloidosis, their clinical team will pass information about them to the NCARDRS. This helps scientists look for better ways to prevent and treat this condition. A person can opt out of the register at any time.\nReferences:\n- https://www.nhs.uk/conditions/amyloidosis/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 969}),
#  Document(page_content="\ufeffQuestions: What are anabolic steroids?\nResponse: Anabolic steroids are prescription-only medicines that copy the effects of the male hormone testosterone. They are manufactured drugs and have limited medical uses. They are not the same as corticosteroids, a different type of steroid drug that's more commonly prescribed.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 970}),
#  Document(page_content="\ufeffQuestions: Are anabolic steroids illegal?\nResponse: Anabolic steroids are class C drugs, which can only be issued by pharmacists with a prescription. It's legal to have anabolic steroids for personal use, but it is illegal to possess, import or export anabolic steroids if it's believed that they are being supplied or sold. This includes giving them to friends. The penalty is an unlimited fine or even a prison sentence of up to 14 years.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 971}),
#  Document(page_content='\ufeffQuestions: Why do people misuse anabolic steroids?\nResponse: Anabolic steroids can be used as performance-enhancing drugs that increase muscle mass and decrease fat, but they can also cause many undesirable effects. Some athletes use them to improve their physical performance and build up their bodies. However, people of all ages misuse these drugs, including adolescent boys who suffer from body dysmorphic disorder.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 972}),
#  Document(page_content="\ufeffQuestions: What is body dysmorphic disorder?\nResponse: Body dysmorphic disorder is a mental health condition where a person spends a lot of time worrying about flaws in their appearance, which are often unnoticeable to others. People with body dysmorphic disorder may take anabolic steroids because they don't see themselves as being physically big enough or strong enough.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 973}),
#  Document(page_content='\ufeffQuestions: What are the physical effects of anabolic steroids on men?\nResponse: The physical effects of anabolic steroids in men can include reduced sperm count, infertility, shrunken testicles, erectile dysfunction, hair loss, breast development, an increased risk of prostate cancer, and severe acne. They may also experience stomach pain.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 974}),
#  Document(page_content='\ufeffQuestions: What are the physical effects of anabolic steroids on women?\nResponse: The physical effects of anabolic steroids in women can include facial hair growth and body hair, loss of breasts, swelling of the clitoris, a deepened voice, an increased sex drive, problems with periods, hair loss, and severe acne.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 975}),
#  Document(page_content="\ufeffQuestions: How are anabolic steroids taken?\nResponse: Anabolic steroids can be injected into a muscle, taken by mouth as tablets, or applied to the skin as creams or gels. Some people may misuse these drugs by taking them in cycles, stacking or pyramiding forms, but there's no evidence that these methods reduce side effects and harms from taking anabolic steroids.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 976}),
#  Document(page_content='\ufeffQuestions: What psychological effects can result from misusing anabolic steroids?\nResponse: Misusing anabolic steroids can cause aggressive behavior, mood swings, paranoia, manic behavior, hallucinations, and delusions. A person who is addicted to anabolic steroids will want to keep using them despite experiencing unpleasant physical side effects.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 977}),
#  Document(page_content='\ufeffQuestions: What medical conditions can develop from taking anabolic steroids?\nResponse: Both men and women who take anabolic steroids can develop any of the following medical conditions: heart attack or stroke, liver or kidney problems or failure, high blood pressure (hypertension), blood clots, and fluid retention or high cholesterol.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 978}),
#  Document(page_content="\ufeffQuestions: Are anabolic steroids addictive?\nResponse: Yes, anabolic steroids are addictive. This means a person can crave the drug, require more to get the same effect, and have withdrawal symptoms if they suddenly stop taking it. When a person is addicted to anabolic steroids, they will want to keep using them despite experiencing unpleasant physical side effects. If you think you're addicted to anabolic steroids, you should see a GP for treatment.\nReferences:\n- https://www.nhs.uk/conditions/anabolic-steroid-misuse/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 979}),
#  Document(page_content='\ufeffQuestions: What is anaesthesia?\nResponse: Anaesthesia means "loss of sensation". Medicines that cause anaesthesia are called anaesthetics. Anaesthetics are used during tests and surgical operations to numb sensation in certain areas of the body or induce sleep.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 980}),
#  Document(page_content='\ufeffQuestions: What are the different types of anaesthesia?\nResponse: There are several types of anaesthesia, including local anaesthetics, general anaesthetics, regional anaesthetic, epidural anaesthetic, spinal anaesthetic, and sedation. The type used depends on the procedure, the area of the body and the preference of the individual.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 981}),
#  Document(page_content="\ufeffQuestions: What is the role of anaesthetists?\nResponse: Anaesthetists are responsible for administering anaesthetic and monitoring the patient's well-being during a procedure. They will discuss the type of anaesthetic, risks or side effects, plan the anaesthetic and pain control, and manage any complications that may arise.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 982}),
#  Document(page_content='\ufeffQuestions: What are the side effects of anaesthesia?\nResponse: Common side effects of anaesthesia include feeling or being sick, dizziness and feeling faint, feeling cold or shivering, headaches, itchiness, bruising, soreness, difficulty peeing, and aches and pains. These side effects usually do not last very long and, if necessary, some of them can be treated.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 983}),
#  Document(page_content='\ufeffQuestions: What are the risks associated with having anaesthesia?\nResponse: Although advances in technology, medicine, and training have made having anaesthesia very safe, there are potential risks of complications, such as permanent nerve damage, allergic reaction to anaesthetic medicine, and death. However, these risks are rare and the benefits usually outweigh the risks.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 984}),
#  Document(page_content='\ufeffQuestions: What is a regional anaesthetic?\nResponse: Regional anaesthetic is a type of anaesthetic given to a specific region of the body. It provides numbness or pain relief for deeper operations where more extensive numbness is needed. There are several types of regional anaesthetic, including epidural anaesthetic and spinal anaesthetic.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 985}),
#  Document(page_content='\ufeffQuestions: What is the difference between local anaesthesia and general anaesthesia?\nResponse: Local anaesthesia is where a small area of the body is numbed, and the individual remains fully conscious. General anaesthesia is where the individual is totally unconscious and unaware of the procedure. Local anaesthesia is often used during minor procedures while general anaesthesia is used for more serious operations.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 986}),
#  Document(page_content='\ufeffQuestions: What is sedation?\nResponse: Sedation is a type of medicine that makes you feel sleepy and relaxed both physically and mentally. It is sometimes used to keep you calm during minor, painful or unpleasant procedures.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 987}),
#  Document(page_content='\ufeffQuestions: How are anaesthetics administered?\nResponse: Anaesthetics can be administered in several ways, including as an ointment, spray, or drops, as an injection into a vein, or as a gas you breathe in.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 988}),
#  Document(page_content='\ufeffQuestions: What factors affect the risk of complications during anaesthesia?\nResponse: The risk of developing complications during anaesthesia depends on several factors, including the individualâ€™s medical history, personal factors (e.g., smoking or being overweight), the type of procedure (e.g., planned or emergency, major or minor), and the type of anaesthetic used. Before the procedure, the anaesthetist will explain any particular risks of potential complications.\nReferences:\n- https://www.nhs.uk/conditions/anaesthesia/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 989}),
#  Document(page_content='\ufeffQuestions: What causes anal cancer?\nResponse: Most anal cancers are caused by an infection called human papillomavirus (HPV), which can be contracted from any skin-to-skin contact of the genital area, vaginal, anal or oral sex, and sharing sex toys.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 990}),
#  Document(page_content='\ufeffQuestions: Who is more likely to get anal cancer?\nResponse: Individuals who have anal sex, are over the age of 75, smoke, have had cervical or vaginal cancer, or have a weakened immune system, such as from HIV or an organ transplant, are more likely to develop anal cancer.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 991}),
#  Document(page_content='\ufeffQuestions: Is anal cancer rare?\nResponse: Yes, anal cancer is rare. However, individuals affected by HPV should get regular checkups to ensure that they do not develop cancer.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 992}),
#  Document(page_content='\ufeffQuestions: What is the best way to protect against anal cancer?\nResponse: The HPV vaccine is one of the best ways to protect against anal cancer. All children aged 12 to 13 are offered the vaccine. It helps protect against cancers caused by HPV, as well as genital warts.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 993}),
#  Document(page_content="\ufeffQuestions: Can anal cancer be prevented?\nResponse: Anal cancer can't always be prevented, but using a condom when having sex to lower your chances of getting HPV, keeping sex toys clean and not sharing them, and trying to quit smoking can lower your chances of getting anal cancer.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 994}),
#  Document(page_content='\ufeffQuestions: What are some symptoms of anal cancer?\nResponse: Common symptoms of anal cancer include bleeding from the anus or rectum, pain, itching, and discharge.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 995}),
#  Document(page_content='\ufeffQuestions: How can one lower their chances of getting anal cancer?\nResponse: One can lower their chances of getting anal cancer by using a condom when having sex to lower their chances of getting HPV, keeping sex toys clean and not sharing them, and trying to quit smoking.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 996}),
#  Document(page_content='\ufeffQuestions: Who should get regular checkups for anal cancer?\nResponse: Individuals affected by HPV should get regular checkups to ensure that they do not develop cancer. Additionally, anyone experiencing symptoms of anal cancer should see a GP.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 997}),
#  Document(page_content='\ufeffQuestions: Can anyone get anal cancer?\nResponse: Yes, anyone can get anal cancer, even if they do not think they have a higher chance of getting it.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>', metadata={'source': 'prepared_1.csv', 'row': 998}),
#  Document(page_content="\ufeffQuestions: What should one do if they experience symptoms of anal cancer?\nResponse: It's important to get any symptoms of anal cancer checked by a GP. Anyone experiencing symptoms such as bleeding from the anus or rectum, pain, itching, and discharge, should see a GP.\nReferences:\n- https://www.nhs.uk/conditions/anal-cancer/causes/ <|eos|> <|eod|>", metadata={'source': 'prepared_1.csv', 'row': 999}),
#  ...]

# %% [markdown]
# # QA function
#
# Chain type, embeddings, similarity search.

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
def qa(file, query, chain_type, k):
  loader = CSVLoader(file)
  documents = loader.load()
  text_splitter = RecursiveCharacterTextSplitter(chunk_size= 500, chunk_overlap = 0)
  docs = text_splitter.split_documents(documents)
  #embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L12-v2")
  embeddings= OpenAIEmbeddings()
  db = FAISS.from_documents(docs, embeddings)
  #db = Chroma.from_documents(texts, embeddings)
  retriever = db.as_retriever(search_type = "similarity", search_kwargs= {"k": k})
  qa = RetrievalQA.from_chain_type(
      llm = OpenAI(), chain_type = chain_type, retriever = retriever, return_source_documents = True
  )
  result = qa({'query': query})
  print(result['result'])
  return result

# %%
result = qa("prepared_1.csv", "Does the Alexander technique teach improved posture and movement, to help reduce and prevent problems caused by unhelpful habits? please do not make up an answer", "map_reduce",2)
# Out:
#  Yes, the Alexander technique teaches improved posture and movement, to help reduce and prevent problems caused by unhelpful habits.

# %%
result = qa("prepared_1.csv", "As mentioned in this document, do Non-pharmaceutical treatments such as photodynamic therapy, comedone extractor, and chemical peels for acne always work? please be honest and please do not make up an answer", "map_reduce", 2)
# Out:
#  These treatments may not always work and should be used only in conjunction with other treatments recommended by a dermatologist.

# %%
result = qa("prepared_1.csv", "According to this document, Are SSRIs suitable for everyone? Please do not make up an answer", "map_reduce", 2)
# Out:
#  No, SSRIs aren't suitable for everyone.

# %%
result = qa("prepared_1.csv", "What is Every Mind Matters website according to this document? Please do not make up an answer", "map_reduce", 2)
# Out:
#  Every Mind Matters is a website that provides tips and resources for improving mental wellbeing and offers practical self-care tips and guidance on where to find further support.
